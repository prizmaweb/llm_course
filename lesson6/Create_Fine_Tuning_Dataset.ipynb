# %% [markdown]
# # BODMAS  task
#
# ## Fine tuning an LLM
#
# If you are using LITE_MODE=True, then please run this on a free T4 box.
#
# If you are using LITE_MODE-False, then please use a paid A100 with high memory.

# %%
import torch
print("Torch:", torch.__version__)
print("CUDA:", torch.version.cuda)
# Out:
# Torch: 2.10.0+cpu
# CUDA: None

# %%
import os
import re
import math
from tqdm import tqdm
from google.colab import userdata
from huggingface_hub import login
import transformers
from datasets import load_dataset, Dataset, DatasetDict
from datetime import datetime
import matplotlib.pyplot as plt

# %%
# Constants
PROJECT_NAME = "BODMAS expression"
HF_USER = "prizmaweb" # your HF name here!

DATA_USER = "prizmaweb"
DATASET_NAME = f"BODMAS"

# %% [markdown]
# ### Log in to HuggingFace
#
#
#
# If you don't already have a HuggingFace account, visit https://huggingface.co to sign up and create a token.
#
# Then select the Secrets for this Notebook by clicking on the key icon in the left, and add a new secret called `HF_TOKEN` with the value as your token.

# %%
# Log in to HuggingFace

hf_token = userdata.get('HF_TOKEN')
login(hf_token, add_to_git_credential=True)

# %%
import json
from google.colab import files
uploaded = files.upload()
with open("bodmas.json") as f:
    data = json.load(f)

print(type(data))
print(data[44])
# Out:
#      <input type="file" id="files-c548d9a0-cd5f-4e7f-86e7-d47ceb8fcedc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c548d9a0-cd5f-4e7f-86e7-d47ceb8fcedc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
bodmas_dataset = load_dataset( "json", data_files={ "train": "bodmas.json", "validation": "bodmas_val.json" } )
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]

# %%
bodmas_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['prompt', 'completion'],
#         num_rows: 50
#     })
#     validation: Dataset({
#         features: ['prompt', 'completion'],
#         num_rows: 15
#     })
# })

# %%
bodmas_dataset.push_to_hub(f"{HF_USER}/bodmas")
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#                               : 100%|##########| 4.36kB / 4.36kB
# ...
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#                               : 100%|##########| 2.73kB / 2.73kB
# README.md:   0%|          | 0.00/416 [00:00<?, ?B/s]
# ...
